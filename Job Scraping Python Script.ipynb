# %%
import csv
from jobspy import scrape_jobs

jobs = scrape_jobs(
    site_name= "Indeed", # "linkedin", "zip_recruiter", "glassdoor"
    search_term="Data Analyst",
    #location="Pittsburgh",
    results_wanted=1000,
    hours_old=7200, # (only Linkedin/Indeed is hour specific, others round up to days old)
    country_indeed='USA'  # only needed for indeed / glassdoor
    #linkedin_fetch_description=True 
    
)
print(f"Found {len(jobs)} jobs")
print(jobs.head())
jobs.to_csv("jobs.csv", quoting=csv.QUOTE_NONNUMERIC, escapechar="\\", index=False)
# Out:
# 2024-07-08 21:27:38,233 - JobSpy - INFO - Indeed search page: 1
# 2024-07-08 21:27:39,830 - JobSpy - INFO - Indeed search page: 2
# 2024-07-08 21:27:41,823 - JobSpy - INFO - Indeed search page: 3
# 2024-07-08 21:27:43,749 - JobSpy - INFO - Indeed search page: 4
# 2024-07-08 21:27:46,059 - JobSpy - INFO - Indeed search page: 5
# 2024-07-08 21:27:48,446 - JobSpy - INFO - Indeed search page: 6
# 2024-07-08 21:27:50,573 - JobSpy - INFO - Indeed search page: 7
# 2024-07-08 21:27:52,848 - JobSpy - INFO - Indeed search page: 8
# 2024-07-08 21:27:55,464 - JobSpy - INFO - Indeed search page: 9
# 2024-07-08 21:27:57,267 - JobSpy - INFO - Indeed search page: 10
# 2024-07-08 21:27:59,009 - JobSpy - INFO - Indeed finished scraping
# Found 1000 jobs
#                  id    site  \
# 0  26821cdd60d8af46  indeed
# 1  a9ae9cf8f714242d  indeed
# 2  a3eb3e3a726bfaa4  indeed
# 3  3fdabbfa20d3f62e  indeed
# 4  7c1b23d220b45f56  indeed
#
#                                              job_url  \
# 0  https://www.indeed.com/viewjob?jk=26821cdd60d8...
# 1  https://www.indeed.com/viewjob?jk=a9ae9cf8f714...
# 2  https://www.indeed.com/viewjob?jk=a3eb3e3a726b...
# 3  https://www.indeed.com/viewjob?jk=3fdabbfa20d3...
# 4  https://www.indeed.com/viewjob?jk=7c1b23d220b4...
#
#                                       job_url_direct  \
# 0  https://careers-nl.icims.com/jobs/1434/job?utm...
# 1  https://newscorp.com/careers/dow-jones/senior-...
# 2  https://rr.jobsyn.org/50A28F3F58944A3DA026FCE3...
# 3  http://www.indeed.com/job/data-migration-analy...
# 4  https://kypersonnelcabinet.csod.com/ats/career...
#
#                                            title                    company  \
# 0                                   Data Analyst  National Louis University
# 1           Senior Data Analyst – Energy Markets                  Dow Jones
# 2  Senior Research Analyst - Natural Gas & Power                  Dow Jones
# 3                         Data Migration Analyst       Dminds Solutions Inc
# 4                Resource Management Analyst III   Commonwealth of Kentucky
#
#             location            job_type date_posted interval  ...  \
# 0    Chicago, IL, US            fulltime  2024-07-08      NaN  ...
# 1    Houston, TX, US                 NaN  2024-07-08      NaN  ...
# 2    Houston, TX, US                 NaN  2024-07-08      NaN  ...
# 3    Toronto, OH, US  fulltime, contract  2024-07-08   yearly  ...
# 4  Frankfort, KY, US            fulltime  2024-07-08   yearly  ...
#
#                      company_url_direct  \
# 0             https://www.nl.edu/about/
# 1               http://www.dowjones.com
# 2               http://www.dowjones.com
# 3                                   NaN
# 4  https://kentucky.gov/Pages/home.aspx
#
#                                    company_addresses  \
# 0                                        Chicago, IL
# 1  1211 Avenue Of The Americas\r\nNew York NY, Un...
# 2  1211 Avenue Of The Americas\r\nNew York NY, Un...
# 3                                                NaN
# 4  229 West Main Street\r\nSuite 400\r\n​Frankfor...
#
#              company_industry  company_num_employees      company_revenue  \
# 0       Education And Schools         1,001 to 5,000  $25M to $100M (USD)
# 1   Media News And Publishing         1,001 to 5,000     $1B to $5B (USD)
# 2   Media News And Publishing         1,001 to 5,000     $1B to $5B (USD)
# 3                         NaN                    NaN                  NaN
# 4                  Government         1,001 to 5,000                  NaN
#
#                                  company_description  \
# 0  National Louis University is an inclusive, inn...
# 1  Dow Jones: We break stories, influence ideas, ...
# 2  Dow Jones: We break stories, influence ideas, ...
# 3                                                NaN
# 4                                                NaN
#
#                                       logo_photo_url  \
# 0  https://d2q79iu7y748jz.cloudfront.net/s/_squar...
# 1  https://d2q79iu7y748jz.cloudfront.net/s/_squar...
# 2  https://d2q79iu7y748jz.cloudfront.net/s/_squar...
# 3                                                NaN
# 4  https://d2q79iu7y748jz.cloudfront.net/s/_squar...
#
#                                     banner_photo_url      ceo_name  \
# 0  https://d2q79iu7y748jz.cloudfront.net/s/_heade...           NaN
# 1  https://d2q79iu7y748jz.cloudfront.net/s/_heade...  Almar Latour
# 2  https://d2q79iu7y748jz.cloudfront.net/s/_heade...  Almar Latour
# 3                                                NaN           NaN
# 4                                                NaN  Andy Beshear
#
#                                        ceo_photo_url
# 0                                                NaN
# 1  https://d2q79iu7y748jz.cloudfront.net/s/_ceoph...
# 2  https://d2q79iu7y748jz.cloudfront.net/s/_ceoph...
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 28 columns]
